# %%
from mplsoccer.pitch import Pitch, VerticalPitch
pitch = Pitch(pitch_color='grass', line_color='white', stripe=True)
fig, ax = pitch.draw()

# %%
pitch = Pitch()  
fig, ax = pitch.draw(figsize =(20,10))

# %%
pitch = Pitch(half=False,pitch_length=100, pitch_width=100,
              axis=True,label=True,pitch_color = '#538053')
fig, ax = pitch.draw(figsize =(20,10))

# %%
pitch = Pitch(half=True)
fig, ax = pitch.draw(figsize =(20,10))

# %%
pitch = Pitch(half=True,pitch_length=100, pitch_width=100,
              axis=True,label=True,pitch_color = '#538053')
fig, ax = pitch.draw(figsize =(20,10))

# %%
pitch = VerticalPitch(half=False)
fig, ax = pitch.draw(figsize =(20,10))

# %%
pitch = VerticalPitch(half=False,pitch_length=100, pitch_width=100,
              axis=True,label=True,pitch_color = '#538053')
fig, ax = pitch.draw(figsize =(20,10))

# %%
pitch = VerticalPitch(half=True)
fig, ax = pitch.draw(figsize =(20,10))

# %%
pitch = VerticalPitch(pitch_length=100, pitch_width=100,
           axis=True,  label=True,pitch_color = '#538053',half=True)
fig,ax =pitch.draw(figsize =(20,10))
