# %%
from mplsoccer import Pitch,VerticalPitch
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# %%
data = pd.read_csv('hm.csv')

# %%
data
# Out:
#      Team     Player               Event  Mins  Secs   X   Y X2 Y2
# 0    Home   suphanan           intercept     0     0  26  87  -  -
# 1    Home   jakkapan                foul     0     0  25  71  -  -
# 2    Home       aris               clear     0     0   9  43  -  -
# 3    Home   peeradol                foul     0     0  53  81  -  -
# 4    Home       aris               clear     0     0   2  24  -  -
# ..    ...        ...                 ...   ...   ...  ..  .. .. ..
# 109  Home      pedro       ShotBlockLeft    42     1  83  66  -  -
# 110  Home   suphanan   ShotOffTargetHead    42     1  92  58  -  -
# 111  Home  jaroensak  ShotOffTargetRight    42     1  81  21  -  -
# 112  Home      pedro      ShotBlockRight    42     1  81  34  -  -
# 113  Home   suphanan  ShotOffTargetRight    42     1  89  46  -  -
#
# [114 rows x 9 columns]

# %%
data['X'] = data['X']*1.2
data['Y'] = data['Y']*.8

# %%
player = "suphanan"
pdata = data[data['Player'] == player ]

# %%
pdatadef = pdata[(pdata['Event'] == 'intercept') | (pdata['Event'] == 'block') |(pdata['Event'] == 'clear') | (pdata['Event'] == 'getball')]

# %%
pdatadef
# Out:
#     Team    Player      Event  Mins  Secs     X     Y X2 Y2
# 0   Home  suphanan  intercept     0     0  31.2  69.6  -  -
# 8   Home  suphanan      block     0     0   8.4  66.4  -  -
# 11  Home  suphanan      clear     0     0   6.0  54.4  -  -
# 17  Home  suphanan  intercept     0     0  33.6  63.2  -  -
# 22  Home  suphanan    getball     0     0  30.0  40.8  -  -
# 32  Home  suphanan      clear     0     0  56.4  74.4  -  -
# 36  Home  suphanan  intercept     0     0  13.2  74.4  -  -
# 37  Home  suphanan      clear     0     0  66.0   5.6  -  -
# 38  Home  suphanan    getball     0     0  34.8  64.8  -  -
# 40  Home  suphanan    getball     0     0  33.6  52.8  -  -
# 51  Home  suphanan      clear     0     0  32.4  60.8  -  -
# 55  Home  suphanan      clear     0     0  42.0  68.0  -  -
# 59  Home  suphanan    getball     0     0   8.4  76.0  -  -
# 60  Home  suphanan      clear     0     0  32.4  68.0  -  -

# %%
pdata
# Out:
#      Team    Player               Event  Mins  Secs      X     Y  X2  Y2
# 0    Home  suphanan           intercept     0     0   31.2  69.6   -   -
# 8    Home  suphanan               block     0     0    8.4  66.4   -   -
# 11   Home  suphanan               clear     0     0    6.0  54.4   -   -
# 17   Home  suphanan           intercept     0     0   33.6  63.2   -   -
# 22   Home  suphanan             getball     0     0   30.0  40.8   -   -
# 32   Home  suphanan               clear     0     0   56.4  74.4   -   -
# 36   Home  suphanan           intercept     0     0   13.2  74.4   -   -
# 37   Home  suphanan               clear     0     0   66.0   5.6   -   -
# 38   Home  suphanan             getball     0     0   34.8  64.8   -   -
# 40   Home  suphanan             getball     0     0   33.6  52.8   -   -
# 51   Home  suphanan               clear     0     0   32.4  60.8   -   -
# 55   Home  suphanan               clear     0     0   42.0  68.0   -   -
# ...

# %%
pitch = VerticalPitch(pitch_length=100, pitch_width=100,
              axis=True, label=True,pitch_color = '#538053')
fig,ax =pitch.draw(figsize =(40,20))
plt.scatter(pdata['Y'],pdata['X'],s = 250)

# %%
pitch = VerticalPitch(pitch_length=100, pitch_width=100,
              axis=True, label=True,pitch_color = '#538053')
fig,ax =pitch.draw(figsize =(40,20))

kde = sns.kdeplot(x = pdata['Y'], y = pdata['X'],
                  fill = True,shade_lowest=False,common_grid=False,
                  alpha=.5,thresh=.01,n_levels=50,cmap = 'magma',cbar=True)
plt.title('Samutprakan City Player_' + player + ' action',size = 30)
# Out:
# Text(0.5, 1.0, 'Samutprakan City Player_suphanan action')

# %%
pitch = VerticalPitch(pitch_length=100, pitch_width=100,
              axis=True, label=True,pitch_color = '#538053')
fig,ax =pitch.draw(figsize =(40,20))

kde = sns.kdeplot(x = pdatadef['Y'], y = pdatadef['X'],
                  fill = True,shade_lowest=False,common_grid=False,
                  alpha=.5,thresh=.01,n_levels=50,cmap = 'magma',cbar=True)
plt.title('Samutprakan City Player_' + player + ' def action',size = 30)
# Out:
# Text(0.5, 1.0, 'Samutprakan City Player_suphanan def action')
