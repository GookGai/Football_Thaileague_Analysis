# %%
from mplsoccer.pitch import Pitch
pitch = Pitch(pitch_color='grass', line_color='white', stripe=True)
fig, ax = pitch.draw()

# %%
pitch = Pitch(pitch_type='opta')  # example plotting an Opta/ Stats Perform pitch
fig, ax = pitch.draw()

# %%
pitch = VerticalPitch(half=False)
fig, ax = pitch.draw()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-39a117b82203> in <module>
# ----> 1 pitch = VerticalPitch(half=False)
#       2 fig, ax = pitch.draw()
#
# NameError: name 'VerticalPitch' is not defined

# %%
pitch = Pitch(half=True)
fig, ax = pitch.draw()
