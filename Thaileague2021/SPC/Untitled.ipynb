# %%
from mplsoccer import Pitch,VerticalPitch
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# %%
data = pd.read_csv('Match1_CRU.csv')

# %%
data
# Out:
#    Team     Player        Event  Mins  Secs    X    Y  X2  Y2
# 0  Away       Yuto     PassFail     3    18  100  100  95  56
# 1  Away  Jaroensak  PassSuccess    15    50  100    0  94  23
# 2  Away       Yuto     PassFail    20    15  100  100  95  59
# 3  Away    Daisuke     PassFail    23    23  100    0  98  45
# 4  Away    Daisuke     PassFail    23    48  100    0  98  44
# 5  Away    Daisuke     PassFail    24    11  100    0  97  50
# 6  Away    Daisuke     PassFail    33     1  100    0  96  48
# 7  Away       Yuto     PassFail    65    54  100  100  95  51

# %%
data['X'] = data['X']*1.2
data['Y'] = data['Y']*.8
data['X2'] = data['X2']*1.2
data['Y2'] = data['Y2']*.8

# %%
data
# Out:
#    Team     Player        Event  Mins  Secs      X     Y     X2    Y2
# 0  Away       Yuto     PassFail     3    18  120.0  80.0  114.0  44.8
# 1  Away  Jaroensak  PassSuccess    15    50  120.0   0.0  112.8  18.4
# 2  Away       Yuto     PassFail    20    15  120.0  80.0  114.0  47.2
# 3  Away    Daisuke     PassFail    23    23  120.0   0.0  117.6  36.0
# 4  Away    Daisuke     PassFail    23    48  120.0   0.0  117.6  35.2
# 5  Away    Daisuke     PassFail    24    11  120.0   0.0  116.4  40.0
# 6  Away    Daisuke     PassFail    33     1  120.0   0.0  115.2  38.4
# 7  Away       Yuto     PassFail    65    54  120.0  80.0  114.0  40.8

# %%
cornerL = data[data['Y'] == 0.0 ]
cornerR = data[data['Y'] == 80.0 ]

# %%
cornerL
# Out:
#    Team     Player        Event  Mins  Secs      X    Y     X2    Y2
# 1  Away  Jaroensak  PassSuccess    15    50  120.0  0.0  112.8  18.4
# 3  Away    Daisuke     PassFail    23    23  120.0  0.0  117.6  36.0
# 4  Away    Daisuke     PassFail    23    48  120.0  0.0  117.6  35.2
# 5  Away    Daisuke     PassFail    24    11  120.0  0.0  116.4  40.0
# 6  Away    Daisuke     PassFail    33     1  120.0  0.0  115.2  38.4

# %%
cornerR
# Out:
#    Team Player     Event  Mins  Secs      X     Y     X2    Y2
# 0  Away   Yuto  PassFail     3    18  120.0  80.0  114.0  44.8
# 2  Away   Yuto  PassFail    20    15  120.0  80.0  114.0  47.2
# 7  Away   Yuto  PassFail    65    54  120.0  80.0  114.0  40.8

# %%
pitch = VerticalPitch(pitch_length=100, pitch_width=100,
        half = True,axis=True, label=True,pitch_color = '#538053')
fig,ax =pitch.draw(figsize =(20,10))

plt.scatter(data['Y2'],data['X2'],s = 300)
plt.title('All Corner Vs CRU',size = 20)
# Out:
# Text(0.5, 1.0, 'All Corner Vs CRU')

# %%
pitch = VerticalPitch(pitch_length=100, pitch_width=100,
        half = True,axis=True,pitch_color = '#538053')
fig,ax =pitch.draw(figsize =(20,10))

gookgai = sns.kdeplot(x = data['Y2'], y = data['X2'],color='b',cmap="Blues",
                  shade = True,shade_lowest=False,alpha=.5,n_levels=100
                  ,thresh=.2)
#plt.scatter(data['Y2'],data['X2'],s = 250)
plt.title('Match1 Samutprakan City',size = 20)
# Out:
# Text(0.5, 1.0, 'Match1 Samutprakan City')

# %%
pitch = VerticalPitch(pitch_length=100, pitch_width=100,
        half = True,axis=True, label=True,pitch_color = '#538053')
fig,ax =pitch.draw(figsize =(20,10))
plt.scatter(cornerL['Y2'],cornerL['X2'],c='#DC143C',s = 300)
plt.scatter(cornerR['Y2'],cornerR['X2'],c='#60D8F6',s = 300)

# %%
pitch = VerticalPitch(pitch_length=100, pitch_width=100,
        half = True,axis=True, label=True,pitch_color = '#538053')
fig,ax =pitch.draw(figsize =(20,10))

gookgai = sns.kdeplot(x = cornerL['Y2'], y = cornerL['X2'],color='b',cmap="Blues",
                  shade = True,shade_lowest=False,alpha=.5,n_levels=100
                  ,thresh=.3)
gookgai2 = sns.kdeplot(x = cornerR['Y2'], y = cornerR['X2'],color='r',cmap="Reds",
                  shade = True,shade_lowest=False,alpha=.5,n_levels=100
                  ,thresh=.3)
#plt.scatter(cornerL['Y2'],cornerL['X2'],s = 300)

# %%
pitch = VerticalPitch(pitch_length=100, pitch_width=100,
        half = True,axis=True, label=True,pitch_color = '#538053')
fig,ax =pitch.draw(figsize =(20,10))

gookgai = sns.kdeplot(x = cornerR['Y2'], y = cornerR['X2'],color='b',cmap="Blues"
                      ,shade = True,shade_lowest=False,alpha=.5,n_levels=1000,thresh=.7
                     )
plt.scatter(cornerR['Y2'],cornerR['X2'],s = 300)
